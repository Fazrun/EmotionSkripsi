# %%
from datetime import datetime

import tensorflow as tf
import sys
import numpy as np
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.models import load_model
import os
import stellargraph as sg
from matplotlib import pyplot as plt
from numpy.testing import measure
from sklearn.semi_supervised.tests.test_self_training import X_train, X_test, y_train, y_test
from stellargraph.mapper import PaddedGraphGenerator
from stellargraph.layer import DeepGraphCNN
from stellargraph import StellarGraph
from stellargraph import datasets
from tensorflow.python.keras.benchmarks.benchmark_util import measure_performance

# %%
num_classes = 5
img_rows, img_cols = 48, 48
batch_size = 32
num_channel = 1
base_dir = 'D:/skripsi bismillahirohmanirahim/test/dataset860'

# %%
train_data_dir = os.path.join('D:/skripsi bismillahirohmanirahim/test/dataset721(860)mix', 'train')
validation_data_dir = os.path.join('D:/skripsi bismillahirohmanirahim/test/dataset721(860)mix', 'val')
test_data_dir = os.path.join('D:/skripsi bismillahirohmanirahim/test/dataset721(860)mix', 'test')

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=30,
    shear_range=0.3,
    zoom_range=0.3,
    width_shift_range=0.4,
    height_shift_range=0.4,
    horizontal_flip=True,
    fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    color_mode='grayscale',
    target_size=(img_rows, img_cols),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)

validation_datagen = ImageDataGenerator(rescale=1. / 255)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    color_mode='grayscale',
    target_size=(img_rows, img_cols),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

test_generator = train_datagen.flow_from_directory(
    test_data_dir,
    color_mode='grayscale',
    target_size=(img_rows, img_cols),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)

print(train_generator.class_indices, validation_generator.class_indices, test_generator.class_indices)

for _ in range(5):
    img, label = train_generator.next()
    print(img.shape)   #  (1,256,256,3)
    plt.imshow(img[0])
    plt.show()
# Out:
# Found 28338 images belonging to 5 classes.
# Found 8095 images belonging to 5 classes.
# Found 4055 images belonging to 5 classes.
# {'marah': 0, 'netral': 1, 'sedih': 2, 'senang': 3, 'terkejut': 4} {'marah': 0, 'netral': 1, 'sedih': 2, 'senang': 3, 'terkejut': 4} {'marah': 0, 'netral': 1, 'sedih': 2, 'senang': 3, 'terkejut': 4}
# (32, 48, 48, 1)
# (32, 48, 48, 1)
# (32, 48, 48, 1)
# (32, 48, 48, 1)
# (32, 48, 48, 1)

# %%
model = Sequential()

# Block-1

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal', input_shape=(img_rows, img_cols, 1)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal', input_shape=(img_rows, img_cols, 1)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# Block-2

model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# Block-3

model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# Block-4

model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

# Block-5

model.add(Flatten())
model.add(Dense(64, kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Block-6

model.add(Dense(64, kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Block-7

model.add(Dense(num_classes, kernel_initializer='he_normal'))
model.add(Activation('softmax'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 48, 48, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 48, 48, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 24, 24, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 24, 24, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 24, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 128)       147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 256)         295168
# _________________________________________________________________
# activation_6 (Activation)    (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 256)         590080
# _________________________________________________________________
# activation_7 (Activation)    (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                147520
# _________________________________________________________________
# activation_8 (Activation)    (None, 64)                0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# activation_9 (Activation)    (None, 64)                0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# _________________________________________________________________
# activation_10 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,328,037
# Trainable params: 1,325,861
# Non-trainable params: 2,176
# _________________________________________________________________
# None

# %%
from tensorflow.keras.optimizers import RMSprop, SGD, Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint('D:/Data fazrun/dataset7/coba_CM_lr001mix.h5',
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=1)

#earlystop = EarlyStopping(monitor='val_loss',
#                          min_delta=0,
#                          patience=3,
#                          verbose=1,
#                          restore_best_weights=True
#                          )

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)

callbacks = [checkpoint, reduce_lr]

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
nb_train_samples = 28338
nb_validation_samples = 8095
epochs = 100

# %%
hist = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Epoch 1/100
# 885/885 [==============================] - 1376s 2s/step - loss: 1.8409 - accuracy: 0.2342 - val_loss: 1.5642 - val_accuracy: 0.2989
#
# Epoch 00001: val_loss improved from inf to 1.56419, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 2/100
# 885/885 [==============================] - 1414s 2s/step - loss: 1.5816 - accuracy: 0.2775 - val_loss: 1.5450 - val_accuracy: 0.2985
#
# Epoch 00002: val_loss improved from 1.56419 to 1.54505, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 3/100
# 885/885 [==============================] - 1109s 1s/step - loss: 1.5548 - accuracy: 0.2969 - val_loss: 1.5427 - val_accuracy: 0.2850
#
# Epoch 00003: val_loss improved from 1.54505 to 1.54273, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 4/100
# 885/885 [==============================] - 1496s 2s/step - loss: 1.5275 - accuracy: 0.3132 - val_loss: 1.4323 - val_accuracy: 0.3993
#
# Epoch 00004: val_loss improved from 1.54273 to 1.43231, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 5/100
# 885/885 [==============================] - 1696s 2s/step - loss: 1.4320 - accuracy: 0.3805 - val_loss: 1.2656 - val_accuracy: 0.5188
#
# Epoch 00005: val_loss improved from 1.43231 to 1.26562, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 6/100
# 885/885 [==============================] - 1207s 1s/step - loss: 1.3100 - accuracy: 0.4584 - val_loss: 1.1152 - val_accuracy: 0.5387
#
# Epoch 00006: val_loss improved from 1.26562 to 1.11524, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 7/100
# 885/885 [==============================] - 1512s 2s/step - loss: 1.2104 - accuracy: 0.5073 - val_loss: 0.9800 - val_accuracy: 0.6086
#
# Epoch 00007: val_loss improved from 1.11524 to 0.97996, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 8/100
# 885/885 [==============================] - 1456s 2s/step - loss: 1.1356 - accuracy: 0.5470 - val_loss: 0.8920 - val_accuracy: 0.6410
#
# Epoch 00008: val_loss improved from 0.97996 to 0.89202, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 9/100
# 885/885 [==============================] - 1279s 1s/step - loss: 1.0838 - accuracy: 0.5688 - val_loss: 1.1077 - val_accuracy: 0.5828
#
# Epoch 00009: val_loss did not improve from 0.89202
# Epoch 10/100
# 885/885 [==============================] - 1490s 2s/step - loss: 1.0544 - accuracy: 0.5867 - val_loss: 0.8049 - val_accuracy: 0.6806
#
# Epoch 00010: val_loss improved from 0.89202 to 0.80495, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 11/100
# 885/885 [==============================] - 1630s 2s/step - loss: 1.0224 - accuracy: 0.5978 - val_loss: 0.7150 - val_accuracy: 0.7273
#
# Epoch 00011: val_loss improved from 0.80495 to 0.71502, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 12/100
# 885/885 [==============================] - 1385s 2s/step - loss: 0.9839 - accuracy: 0.6188 - val_loss: 0.7508 - val_accuracy: 0.7094
#
# Epoch 00012: val_loss did not improve from 0.71502
# Epoch 13/100
# 885/885 [==============================] - 1478s 2s/step - loss: 0.9600 - accuracy: 0.6293 - val_loss: 0.7380 - val_accuracy: 0.7158
#
# Epoch 00013: val_loss did not improve from 0.71502
# Epoch 14/100
# 885/885 [==============================] - 903s 1s/step - loss: 0.9389 - accuracy: 0.6373 - val_loss: 0.7040 - val_accuracy: 0.7378
#
# Epoch 00014: val_loss improved from 0.71502 to 0.70401, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 15/100
# 885/885 [==============================] - 125s 141ms/step - loss: 0.9247 - accuracy: 0.6461 - val_loss: 0.6856 - val_accuracy: 0.7344
#
# Epoch 00015: val_loss improved from 0.70401 to 0.68559, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 16/100
# 885/885 [==============================] - 125s 141ms/step - loss: 0.9097 - accuracy: 0.6509 - val_loss: 0.6937 - val_accuracy: 0.7256
#
# Epoch 00016: val_loss did not improve from 0.68559
# Epoch 17/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.8963 - accuracy: 0.6553 - val_loss: 0.6953 - val_accuracy: 0.7365
#
# Epoch 00017: val_loss did not improve from 0.68559
# Epoch 18/100
# 885/885 [==============================] - 125s 141ms/step - loss: 0.8844 - accuracy: 0.6627 - val_loss: 0.7146 - val_accuracy: 0.7266
#
# Epoch 00018: val_loss did not improve from 0.68559
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 19/100
# 885/885 [==============================] - 125s 141ms/step - loss: 0.8392 - accuracy: 0.6799 - val_loss: 0.6013 - val_accuracy: 0.7716
#
# Epoch 00019: val_loss improved from 0.68559 to 0.60133, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 20/100
# 885/885 [==============================] - 124s 141ms/step - loss: 0.8229 - accuracy: 0.6872 - val_loss: 0.5920 - val_accuracy: 0.7703
#
# Epoch 00020: val_loss improved from 0.60133 to 0.59204, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 21/100
# 885/885 [==============================] - 125s 141ms/step - loss: 0.8237 - accuracy: 0.6841 - val_loss: 0.5888 - val_accuracy: 0.7715
#
# Epoch 00021: val_loss improved from 0.59204 to 0.58881, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 22/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.8105 - accuracy: 0.6935 - val_loss: 0.5863 - val_accuracy: 0.7752
#
# Epoch 00022: val_loss improved from 0.58881 to 0.58632, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 23/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.8103 - accuracy: 0.6932 - val_loss: 0.5854 - val_accuracy: 0.7757
#
# Epoch 00023: val_loss improved from 0.58632 to 0.58542, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 24/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7990 - accuracy: 0.6973 - val_loss: 0.5886 - val_accuracy: 0.7741
#
# Epoch 00024: val_loss did not improve from 0.58542
# Epoch 25/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7918 - accuracy: 0.7003 - val_loss: 0.5773 - val_accuracy: 0.7796
#
# Epoch 00025: val_loss improved from 0.58542 to 0.57734, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 26/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7948 - accuracy: 0.6988 - val_loss: 0.5764 - val_accuracy: 0.7778
#
# Epoch 00026: val_loss improved from 0.57734 to 0.57645, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 27/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7877 - accuracy: 0.7026 - val_loss: 0.5756 - val_accuracy: 0.7774
#
# Epoch 00027: val_loss improved from 0.57645 to 0.57560, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 28/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7901 - accuracy: 0.6972 - val_loss: 0.5797 - val_accuracy: 0.7754
#
# Epoch 00028: val_loss did not improve from 0.57560
# Epoch 29/100
# 885/885 [==============================] - 127s 143ms/step - loss: 0.7899 - accuracy: 0.6996 - val_loss: 0.5789 - val_accuracy: 0.7781
#
# Epoch 00029: val_loss did not improve from 0.57560
# Epoch 30/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7841 - accuracy: 0.7033 - val_loss: 0.5744 - val_accuracy: 0.7785
#
# Epoch 00030: val_loss improved from 0.57560 to 0.57440, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 31/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7793 - accuracy: 0.7014 - val_loss: 0.5706 - val_accuracy: 0.7814
#
# Epoch 00031: val_loss improved from 0.57440 to 0.57061, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 32/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7785 - accuracy: 0.7072 - val_loss: 0.5672 - val_accuracy: 0.7810
#
# Epoch 00032: val_loss improved from 0.57061 to 0.56723, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 33/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7735 - accuracy: 0.7060 - val_loss: 0.5608 - val_accuracy: 0.7819
#
# Epoch 00033: val_loss improved from 0.56723 to 0.56084, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 34/100
# 885/885 [==============================] - 125s 141ms/step - loss: 0.7665 - accuracy: 0.7099 - val_loss: 0.5621 - val_accuracy: 0.7839
#
# Epoch 00034: val_loss did not improve from 0.56084
# Epoch 35/100
# 885/885 [==============================] - 132s 150ms/step - loss: 0.7607 - accuracy: 0.7131 - val_loss: 0.5602 - val_accuracy: 0.7842
#
# Epoch 00035: val_loss improved from 0.56084 to 0.56017, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 36/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7628 - accuracy: 0.7124 - val_loss: 0.5557 - val_accuracy: 0.7852
#
# Epoch 00036: val_loss improved from 0.56017 to 0.55567, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 37/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7692 - accuracy: 0.7099 - val_loss: 0.5582 - val_accuracy: 0.7856
#
# Epoch 00037: val_loss did not improve from 0.55567
# Epoch 38/100
# 885/885 [==============================] - 124s 141ms/step - loss: 0.7553 - accuracy: 0.7105 - val_loss: 0.5537 - val_accuracy: 0.7875
#
# Epoch 00038: val_loss improved from 0.55567 to 0.55375, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 39/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7581 - accuracy: 0.7135 - val_loss: 0.5523 - val_accuracy: 0.7881
#
# Epoch 00039: val_loss improved from 0.55375 to 0.55229, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 40/100
# 885/885 [==============================] - 126s 142ms/step - loss: 0.7498 - accuracy: 0.7175 - val_loss: 0.5539 - val_accuracy: 0.7893
#
# Epoch 00040: val_loss did not improve from 0.55229
# Epoch 41/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7478 - accuracy: 0.7176 - val_loss: 0.5569 - val_accuracy: 0.7872
#
# Epoch 00041: val_loss did not improve from 0.55229
# Epoch 42/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7555 - accuracy: 0.7136 - val_loss: 0.5559 - val_accuracy: 0.7877
#
# Epoch 00042: val_loss did not improve from 0.55229
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 43/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7460 - accuracy: 0.7183 - val_loss: 0.5493 - val_accuracy: 0.7907
#
# Epoch 00043: val_loss improved from 0.55229 to 0.54929, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 44/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7483 - accuracy: 0.7159 - val_loss: 0.5451 - val_accuracy: 0.7912
#
# Epoch 00044: val_loss improved from 0.54929 to 0.54513, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 45/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7404 - accuracy: 0.7224 - val_loss: 0.5459 - val_accuracy: 0.7910
#
# Epoch 00045: val_loss did not improve from 0.54513
# Epoch 46/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7431 - accuracy: 0.7210 - val_loss: 0.5450 - val_accuracy: 0.7919
#
# Epoch 00046: val_loss improved from 0.54513 to 0.54504, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 47/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7405 - accuracy: 0.7186 - val_loss: 0.5460 - val_accuracy: 0.7907
#
# Epoch 00047: val_loss did not improve from 0.54504
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 48/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7375 - accuracy: 0.7227 - val_loss: 0.5434 - val_accuracy: 0.7930
#
# Epoch 00048: val_loss improved from 0.54504 to 0.54335, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 49/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7426 - accuracy: 0.7192 - val_loss: 0.5443 - val_accuracy: 0.7920
#
# Epoch 00049: val_loss did not improve from 0.54335
# Epoch 50/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7434 - accuracy: 0.7191 - val_loss: 0.5440 - val_accuracy: 0.7928
#
# Epoch 00050: val_loss did not improve from 0.54335
# Epoch 51/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7340 - accuracy: 0.7225 - val_loss: 0.5435 - val_accuracy: 0.7943
#
# Epoch 00051: val_loss did not improve from 0.54335
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 52/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7419 - accuracy: 0.7199 - val_loss: 0.5439 - val_accuracy: 0.7935
#
# Epoch 00052: val_loss did not improve from 0.54335
# Epoch 53/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7378 - accuracy: 0.7213 - val_loss: 0.5444 - val_accuracy: 0.7930
#
# Epoch 00053: val_loss did not improve from 0.54335
# Epoch 54/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7412 - accuracy: 0.7210 - val_loss: 0.5450 - val_accuracy: 0.7915
#
# Epoch 00054: val_loss did not improve from 0.54335
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 55/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7396 - accuracy: 0.7198 - val_loss: 0.5433 - val_accuracy: 0.7934
#
# Epoch 00055: val_loss improved from 0.54335 to 0.54335, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 56/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7396 - accuracy: 0.7195 - val_loss: 0.5455 - val_accuracy: 0.7919
#
# Epoch 00056: val_loss did not improve from 0.54335
# Epoch 57/100
# 885/885 [==============================] - 126s 143ms/step - loss: 0.7341 - accuracy: 0.7236 - val_loss: 0.5437 - val_accuracy: 0.7933
#
# Epoch 00057: val_loss did not improve from 0.54335
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 58/100
# 885/885 [==============================] - 126s 142ms/step - loss: 0.7358 - accuracy: 0.7238 - val_loss: 0.5431 - val_accuracy: 0.7928
#
# Epoch 00058: val_loss improved from 0.54335 to 0.54315, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 59/100
# 885/885 [==============================] - 127s 143ms/step - loss: 0.7319 - accuracy: 0.7222 - val_loss: 0.5437 - val_accuracy: 0.7925
#
# Epoch 00059: val_loss did not improve from 0.54315
# Epoch 60/100
# 885/885 [==============================] - 148s 167ms/step - loss: 0.7326 - accuracy: 0.7226 - val_loss: 0.5430 - val_accuracy: 0.7932
#
# Epoch 00060: val_loss improved from 0.54315 to 0.54305, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 61/100
# 885/885 [==============================] - 130s 147ms/step - loss: 0.7341 - accuracy: 0.7239 - val_loss: 0.5435 - val_accuracy: 0.7933
#
# Epoch 00061: val_loss did not improve from 0.54305
# Epoch 62/100
# 885/885 [==============================] - 123s 138ms/step - loss: 0.7334 - accuracy: 0.7241 - val_loss: 0.5439 - val_accuracy: 0.7925
#
# Epoch 00062: val_loss did not improve from 0.54305
# Epoch 63/100
# 885/885 [==============================] - 126s 142ms/step - loss: 0.7339 - accuracy: 0.7231 - val_loss: 0.5448 - val_accuracy: 0.7923
#
# Epoch 00063: val_loss did not improve from 0.54305
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 64/100
# 885/885 [==============================] - 130s 147ms/step - loss: 0.7331 - accuracy: 0.7219 - val_loss: 0.5433 - val_accuracy: 0.7937
#
# Epoch 00064: val_loss did not improve from 0.54305
# Epoch 65/100
# 885/885 [==============================] - 130s 147ms/step - loss: 0.7362 - accuracy: 0.7224 - val_loss: 0.5430 - val_accuracy: 0.7937
#
# Epoch 00065: val_loss improved from 0.54305 to 0.54302, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 66/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7440 - accuracy: 0.7202 - val_loss: 0.5428 - val_accuracy: 0.7937
#
# Epoch 00066: val_loss improved from 0.54302 to 0.54278, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 67/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7350 - accuracy: 0.7237 - val_loss: 0.5430 - val_accuracy: 0.7935
#
# Epoch 00067: val_loss did not improve from 0.54278
# Epoch 68/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7368 - accuracy: 0.7202 - val_loss: 0.5434 - val_accuracy: 0.7920
#
# Epoch 00068: val_loss did not improve from 0.54278
# Epoch 69/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7306 - accuracy: 0.7218 - val_loss: 0.5427 - val_accuracy: 0.7924
#
# Epoch 00069: val_loss improved from 0.54278 to 0.54273, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# Epoch 70/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7366 - accuracy: 0.7220 - val_loss: 0.5427 - val_accuracy: 0.7941
#
# Epoch 00070: val_loss did not improve from 0.54273
# Epoch 71/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7373 - accuracy: 0.7202 - val_loss: 0.5442 - val_accuracy: 0.7933
#
# Epoch 00071: val_loss did not improve from 0.54273
# Epoch 72/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7329 - accuracy: 0.7256 - val_loss: 0.5441 - val_accuracy: 0.7927
#
# Epoch 00072: val_loss did not improve from 0.54273
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# Epoch 73/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7336 - accuracy: 0.7239 - val_loss: 0.5444 - val_accuracy: 0.7929
#
# Epoch 00073: val_loss did not improve from 0.54273
# Epoch 74/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7327 - accuracy: 0.7224 - val_loss: 0.5421 - val_accuracy: 0.7928
#
# Epoch 00074: val_loss improved from 0.54273 to 0.54205, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 75/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7359 - accuracy: 0.7227 - val_loss: 0.5455 - val_accuracy: 0.7919
#
# Epoch 00075: val_loss did not improve from 0.54205
# Epoch 76/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7349 - accuracy: 0.7217 - val_loss: 0.5426 - val_accuracy: 0.7935
#
# Epoch 00076: val_loss did not improve from 0.54205
# Epoch 77/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7346 - accuracy: 0.7244 - val_loss: 0.5442 - val_accuracy: 0.7930
#
# Epoch 00077: val_loss did not improve from 0.54205
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# Epoch 78/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7334 - accuracy: 0.7226 - val_loss: 0.5445 - val_accuracy: 0.7930
#
# Epoch 00078: val_loss did not improve from 0.54205
# Epoch 79/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7364 - accuracy: 0.7204 - val_loss: 0.5444 - val_accuracy: 0.7910
#
# Epoch 00079: val_loss did not improve from 0.54205
# Epoch 80/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7363 - accuracy: 0.7228 - val_loss: 0.5415 - val_accuracy: 0.7939
#
# Epoch 00080: val_loss improved from 0.54205 to 0.54150, saving model to D:/Data fazrun/dataset7\coba_CM_lr001mix.h5
# Epoch 81/100
# 885/885 [==============================] - 122s 138ms/step - loss: 0.7374 - accuracy: 0.7200 - val_loss: 0.5439 - val_accuracy: 0.7922
#
# Epoch 00081: val_loss did not improve from 0.54150
# Epoch 82/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7383 - accuracy: 0.7229 - val_loss: 0.5431 - val_accuracy: 0.7928
#
# Epoch 00082: val_loss did not improve from 0.54150
# Epoch 83/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7451 - accuracy: 0.7195 - val_loss: 0.5419 - val_accuracy: 0.7939
#
# Epoch 00083: val_loss did not improve from 0.54150
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# Epoch 84/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7397 - accuracy: 0.7216 - val_loss: 0.5438 - val_accuracy: 0.7938
#
# Epoch 00084: val_loss did not improve from 0.54150
# Epoch 85/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7350 - accuracy: 0.7241 - val_loss: 0.5425 - val_accuracy: 0.7941
#
# Epoch 00085: val_loss did not improve from 0.54150
# Epoch 86/100
# 885/885 [==============================] - 126s 143ms/step - loss: 0.7381 - accuracy: 0.7216 - val_loss: 0.5429 - val_accuracy: 0.7939
#
# Epoch 00086: val_loss did not improve from 0.54150
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# Epoch 87/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7339 - accuracy: 0.7217 - val_loss: 0.5431 - val_accuracy: 0.7939
#
# Epoch 00087: val_loss did not improve from 0.54150
# Epoch 88/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7357 - accuracy: 0.7209 - val_loss: 0.5440 - val_accuracy: 0.7924
#
# Epoch 00088: val_loss did not improve from 0.54150
# Epoch 89/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7352 - accuracy: 0.7223 - val_loss: 0.5438 - val_accuracy: 0.7930
#
# Epoch 00089: val_loss did not improve from 0.54150
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# Epoch 90/100
# 885/885 [==============================] - 123s 139ms/step - loss: 0.7395 - accuracy: 0.7216 - val_loss: 0.5440 - val_accuracy: 0.7924
#
# Epoch 00090: val_loss did not improve from 0.54150
# Epoch 91/100
# 885/885 [==============================] - 125s 141ms/step - loss: 0.7290 - accuracy: 0.7245 - val_loss: 0.5438 - val_accuracy: 0.7928
#
# Epoch 00091: val_loss did not improve from 0.54150
# Epoch 92/100
# 885/885 [==============================] - 125s 142ms/step - loss: 0.7316 - accuracy: 0.7226 - val_loss: 0.5425 - val_accuracy: 0.7934
#
# Epoch 00092: val_loss did not improve from 0.54150
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# Epoch 93/100
# 885/885 [==============================] - 126s 143ms/step - loss: 0.7353 - accuracy: 0.7218 - val_loss: 0.5416 - val_accuracy: 0.7934
#
# Epoch 00093: val_loss did not improve from 0.54150
# Epoch 94/100
# 885/885 [==============================] - 125s 142ms/step - loss: 0.7293 - accuracy: 0.7244 - val_loss: 0.5436 - val_accuracy: 0.7934
#
# Epoch 00094: val_loss did not improve from 0.54150
# Epoch 95/100
# 885/885 [==============================] - 125s 142ms/step - loss: 0.7426 - accuracy: 0.7197 - val_loss: 0.5429 - val_accuracy: 0.7920
#
# Epoch 00095: val_loss did not improve from 0.54150
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.
# Epoch 96/100
# 885/885 [==============================] - 125s 142ms/step - loss: 0.7419 - accuracy: 0.7207 - val_loss: 0.5444 - val_accuracy: 0.7932
#
# Epoch 00096: val_loss did not improve from 0.54150
# Epoch 97/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7397 - accuracy: 0.7190 - val_loss: 0.5421 - val_accuracy: 0.7937
#
# Epoch 00097: val_loss did not improve from 0.54150
# Epoch 98/100
# 885/885 [==============================] - 125s 141ms/step - loss: 0.7350 - accuracy: 0.7200 - val_loss: 0.5434 - val_accuracy: 0.7929
#
# Epoch 00098: val_loss did not improve from 0.54150
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 6.553600300244697e-15.
# Epoch 99/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7348 - accuracy: 0.7226 - val_loss: 0.5438 - val_accuracy: 0.7928
#
# Epoch 00099: val_loss did not improve from 0.54150
# Epoch 100/100
# 885/885 [==============================] - 124s 140ms/step - loss: 0.7358 - accuracy: 0.7214 - val_loss: 0.5438 - val_accuracy: 0.7928
#
# Epoch 00100: val_loss did not improve from 0.54150

# %%
sg.utils.plot_history(hist)
plt.savefig('GraphEmotionMIXVGG.png')
plt.show()

# %%
train_loss=hist.history['loss']
val_loss=hist.history['val_loss']
train_acc=hist.history['accuracy']
val_acc=hist.history['val_accuracy']
xc=range(epochs)

plt.figure(1,figsize=(7,5))
plt.plot(xc,train_loss)#####################
plt.plot(xc,val_loss)
plt.xlabel('num of Epochs')
plt.ylabel('loss')
plt.title('train_loss vs val_loss')
plt.grid(True)
plt.legend(['train','val'])
#print plt.style.available # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])

plt.figure(2,figsize=(7,5))
plt.plot(xc,train_acc)
plt.plot(xc,val_acc)
plt.xlabel('num of Epochs')
plt.ylabel('accuracy')
plt.title('train_acc vs val_acc')
plt.grid(True)
plt.legend(['train','val'],loc=4)
#print plt.style.available # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])

# %%
X_train, y_train = next(train_generator)
X_val, y_val = next(validation_generator)
X_test, y_test = next(test_generator)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

model = load_model('D:/Data fazrun/dataset7/coba_CM_lr001mix.h5')

predictions = model.predict(X_test, steps=len(X_test), verbose=0)
#y_pred=model.predict(x_test)
#y_pred = np.round(y_pred)
y_pred = np.argmax(predictions, axis=-1)

y_true=np.argmax(y_test, axis=-1)

cm = confusion_matrix(y_true, y_pred)

## Get Class Labels
labels = ['class 0(marah)', 'class 1(netral)', 'class 2(sedih)', 'class 3(senang)', 'class 4(terkejut)']
class_names = labels

# Plot confusion matrix in a beautiful manner
fig = plt.figure(figsize=(16, 14))
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, fmt = 'g'); #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted', fontsize=20)
ax.xaxis.set_label_position('bottom')
plt.xticks(rotation=90)
ax.xaxis.set_ticklabels(class_names, fontsize = 10)
ax.xaxis.tick_bottom()

ax.set_ylabel('True', fontsize=20)
ax.yaxis.set_ticklabels(class_names, fontsize = 10)
plt.yticks(rotation=0)

plt.title('Refined Confusion Matrix', fontsize=20)

plt.savefig('ConMatmix.png')
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score

print("Precision Score : ",precision_score(y_true, y_pred, 
                                           average='micro'))
print("Recall Score : ",recall_score(y_true, y_pred, 
                                     average='micro'))
# Out:
# Precision Score :  0.84375
# Recall Score :  0.84375

# %%
from sklearn.metrics import f1_score

print("F1 Score : ",f1_score(y_true, y_pred, 
                             average='micro'))
# Out:
# F1 Score :  0.84375
